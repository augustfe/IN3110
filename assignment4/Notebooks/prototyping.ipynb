# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from copy import copy
from dataclasses import dataclass

import bs4
import pandas as pd
from bs4 import BeautifulSoup

# %%
sample_table = """
<table>
  <tr>
    <th>Date</th>
    <th>Venue</th>
    <th>Type</th>
    <th>Info</th>
  </tr>
  <tr>
    <td>October</td>
    <td rowspan="2">UiO</td>
    <td>Assignment 3</td>
    <td>image filters</td>
  </tr>
  <tr>
    <td>November</td>
    <td colspan="2">Assignment 4</td>
  </tr>
</table>
"""
table = BeautifulSoup(sample_table, "html.parser")

# %%
rows = table.find("tr")
headers = {}
head_n = []

columns = rows.find_all("th")
# Get headers
for column in columns:
    headers[column.next] = ['']*2
    head_n += [column.next]

rows = table.find_all("tr")
for i, row in enumerate(rows[1:]):
    elements = row.find_all("td")
    for elem, key in zip(elements, headers):
        print(elem.next)
        headers[key][i] = elem.next
    print("\n")
    #print(row)
    #print("\n")

# headers
df = pd.DataFrame(data=headers, columns=head_n)
df_2 = pd.read_html(sample_table)[0][["Date", "Venue", "Type"]]
#print(df_2.to_markdown())
df_2 = df_2.reset_index(drop=True)
df_2
# Out:
# October
# UiO
# Assignment 3
# image filters
#
#
# November
# Assignment 4
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [3], line 23
#      18     #print(row)
#      19     #print("\n")
#      20
#      21 # headers
#      22 df = pd.DataFrame(data=headers, columns=head_n)
# ---> 23 df_2 = pd.read_html(sample_table)[0][["Date", "Venue", "Type"]]
#      24 #print(df_2.to_markdown())
#      25 df_2 = df_2.reset_index(drop=True)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
best = {}

all_players = {'Golden State': [{'name': 'Bjelica, Nemanja', 'url': 'https://en.wikipedia.org/wiki/Nemanja_Bjelica', 'points': 6.1, 'rebounds': 4.1, 'assists': 2.2}, {'name': 'Chiozza, Chris', 'url': 'https://en.wikipedia.org/wiki/Chris_Chiozza', 'points': 2.0, 'rebounds': 1.1, 'assists': 1.9}, {'name': 'Curry, Stephen', 'url': 'https://en.wikipedia.org/wiki/Stephen_Curry', 'points': 0, 'rebounds': 0, 'assists': 0}, {'name': 'Green, Draymond', 'url': 'https://en.wikipedia.org/wiki/Draymond_Green', 'points': 7.5, 'rebounds': 7.3, 'assists': 7.0}, {'name': 'Iguodala, Andre', 'url': 'https://en.wikipedia.org/wiki/Andre_Iguodala', 'points': 4.0, 'rebounds': 3.2, 'assists': 3.7}, {'name': 'Kuminga, Jonathan', 'url': 'https://en.wikipedia.org/wiki/Jonathan_Kuminga', 'points': 9.3, 'rebounds': 3.3, 'assists': 0.9}, {'name': 'Lee, Damion', 'url': 'https://en.wikipedia.org/wiki/Damion_Lee', 'points': 7.4, 'rebounds': 3.2, 'assists': 1.0}, {'name': 'Looney, Kevon', 'url': 'https://en.wikipedia.org/wiki/Kevon_Looney', 'points': 6.0, 'rebounds': 7.3, 'assists': 2.0}, {'name': 'Moody, Moses', 'url': 'https://en.wikipedia.org/wiki/Moses_Moody', 'points': 4.4, 'rebounds': 1.5, 'assists': 0.4}, {'name': 'Payton, Gary, II', 'url': 'https://en.wikipedia.org/wiki/Gary_
Al', 'url': 'https://en.wikipedia.org/wiki/Al_Horford', 'points': 10.2, 'rebounds': 7.7, 'assists': 3.4}, {'name': 'Kornet, Luke', 'url': 'https://en.wikipedia.org/wiki/Luke_Kornet', 'points': 2.2, 'rebounds': 2.1, 'assists': 0.7}, {'name': 'Morgan, Juwan', 'url': 'https://en.wikipedia.org/wiki/Juwan_Morgan', 'points': 0, 'rebounds': 0, 'assists': 0}, {'name': 'Nesmith, Aaron', 'url': 'https://en.wikipedia.org/wiki/Aaron_Nesmith', 'points': 3.8, 'rebounds': 1.7, 'assists': 0.4}, {'name': 'Pritchard, Payton', 'url': 'https://en.wikipedia.org/wiki/Payton_Pritchard', 'points': 6.2, 'rebounds': 1.9, 'assists': 2.0}, {'name': 'Ryan, Matt', 'url': 'https://en.wikipedia.org/wiki/Matt_Ryan_(basketball)', 'points': 3.0, 'rebounds': 0.0, 'assists': 0.0}, {'name': 'Smart, Marcus', 'url': 'https://en.wikipedia.org/wiki/Marcus_Smart', 'points': 12.1, 'rebounds': 3.8, 'assists': 5.9}, {'name': 'Stauskas, Nik', 'url': 'https://en.wikipedia.org/wiki/Nik_Stauskas', 'points': 0, 'rebounds': 0, 'assists': 0}, {'name': 'Tatum, Jayson', 'url': 'https://en.wikipedia.org/wiki/Jayson_Tatum', 'points': 26.9, 'rebounds': 8.0, 'assists': 4.4}, {'name': 'Theis, Daniel', 'url': 'https://en.wikipedia.org/wiki/Daniel_Theis', 'points': 7.9, 'rebounds': 4.7, 'assists': 1.0}, {'name': 'Thomas, Brodric', 'url': 'https://en.wikipedia.org/wiki/Brodric_Thomas', 'points': 1.8, 'rebounds': 0.8, 'assists': 0.9}, {'name': 'White, Derrick', 'url': 'https://en.wikipedia.org/wiki/Derrick_White_(basketball)', 'points': 0, 'rebounds': 0, 'assists': 0}, {'name': 'Williams, Grant', 'url': 'https://en.wikipedia.org/wiki/Grant_Williams_(basketball)', 'points': 7.8, 'rebounds': 3.6, 'assists': 1.0}, {'name': 'Williams, Robert III', 'url': 'https://en.wikipedia.org/wiki/Robert_Williams_III', 'points': 10.0, 'rebounds': 9.6, 'assists': 2.0}]}
for team in all_players:
    fbest = 0
    sbest = 0
    tbest = 0
    fname = ''
    sname = ''
    tname = ''
    for player in all_players[team]:
        pscore = player["points"]
        if pscore > fbest:
            tbest = sbest
            tname = sname
            sbest = fbest
            sname = fname
            fbest = pscore
            fname = player
        elif pscore > sbest:
            tbest = sbest
            tname = sname
            sbest = pscore
            sname = player
        elif pscore > tbest:
            tname = player
            tbest = pscore
    best[team] = [fname, sname, tname]

# %%
# Out:
# Creating NBA_player_statistics/points.png
# Creating NBA_player_statistics/assists.png
# Creating NBA_player_statistics/rebounds.png

# %%
color_table = {
    "Golden State": "#1D428A",
    "Philadelphia": "#006BB6",
    "Miami": "#98002E",
    "Memphis": "#5D76A9",
    "Milwaukee": "#00471B",
    "Phoenix": "#1D1160",
    "Dallas": "#00538C",
    "Boston": "#007A33",
}

def plot_NBA_player_statistics(teams, stat="points"):
    """Plot NBA player statistics. In this case, just points"""
    count_so_far = 0
    all_names = []
    spacing = []
    max_points = 0
    #plt.figure(figsize=(6, 8))
    # iterate through each team and the
    for team, players in teams.items():
        # pick the color for the team, from the table above
        # color = color_table[team]
        # collect the points and name of each player on the team
        # you'll want to repeat with other stats as well
        points = []
        names = []
        
        color = color_table[team]
        for player in players:
            names.append(player["name"])
            points.append(player[stat])
        # record all the names, for use later in x label
        all_names.extend(names)

        # the position of bars is shifted by the number of players so far
        x = np.arange(count_so_far, count_so_far + len(players))
        count_so_far += len(players)
        # make bars for this team's players points,
        # with the team name as the label
        #this_space = 
        #print(x[1])
        spacing.append(x[1] + count_so_far/2)
        #print(spacing)
        bars = plt.bar(x + count_so_far/2, points, color=color, label=team)
        # add the value as text on the bars
        plt.bar_label(bars, labels=names, rotation=90, size=6, padding=3)
        max_points = np.max([np.max(points), max_points])
    #print(spacing)
    # use the names, rotated 90 degrees as the labels for the bars
    plt.xticks(spacing, teams, rotation=90)
    # add the legend with the colors  for each team
    #plt.legend(ncol=4, columnspacing=0.8)
    plt.legend(loc=2, ncol=3, fontsize=7)
    # turn off gridlines
    plt.grid(False)
    plt.ylim(0, max_points*5/3)
    # set the title
    plt.title("points per game")
    # save the figure to a file
    filename = f"NBA_player_statistics/{stat}.png"
    print(f"Creating {filename}")
    plt.tight_layout()
    plt.savefig(filename)
    plt.clf()


plot_NBA_player_statistics(best, "points")
plot_NBA_player_statistics(best, "assists")
plot_NBA_player_statistics(best, "rebounds")

# %%
from email.policy import default
from typing import List  # isort:skip
import os
import re
from operator import itemgetter
from typing import Dict, List
from urllib.parse import urljoin
from collections import Counter

import numpy as np
from bs4 import BeautifulSoup
from matplotlib import pyplot as plt
from filter_urls import find_articles, find_urls
from requesting_urls import get_html
from collections import defaultdict
import requests
from numba import jit, types, optional, deferred_type
from numba.experimental import jitclass

def better_articles(html):
  base_url = "https://en.wikipedia.org"
  articles = set()
  #print(html)
  # response = requests.get(url, params=None)
  #html_str = response.text
  long_pat = re.compile(r"(?<=href=\")((http\:\/\/en\.wikipedia[^#\\\"]+)|(\/wiki[^#\"]+))")
  
  for article in long_pat.findall(html):
    # print(article)
    # print(url)
    # quit()
    # article = long_pat.search(long_tag)
    if article is not None:
      if (article[0][0] == "/"):
        article = base_url + article[0]
      else:
        article = article[0]
      if not ":" in article[6:]:
        articles.add(article)
  
  return articles

node_type = deferred_type()
spec = [('data', types.unicode_type),
        ('last', optional(node_type)),
        ('next', optional(node_type))]

class Node:
  def __init__(self, data):
    self.data = data
    self.last = None
    self.next = None
  
  def set_prev(self, last):
    self.last = last

# node_type.define(Node.class_type.instance_type)

class LinkedList:
  def __init__(self):
    self.head = None

class Graph:

  def __init__(self, target):
    self.graph = defaultdict(list)
    self.trail = {}
    self.target = target
    #self.ll = LinkedList()
    self.nodes = {}

  def extendGraph(self, node):
    html: str = get_html(node)
    articles = better_articles(html)
    for article in articles:
      if article != node:
        self.addEdge(node, article)

  def addEdge(self, u, v):
    self.graph[u].append(v)
    
    # print(v in self.trail)
    if not v in self.trail:
      node = Node(v)
      self.trail[v] = node
      #self.nodes.append(Node(v))
      # Node(v).set_prev(self.trail[u])
      node.last = self.trail[u]
    # if u == v:
      # print(u)
    # print(node.data, node.last.data)
    #print(Node(v).last, self.trail[u])
    #print(self.trail[u])
    #print(node.last)

  def Search(self, start):
    # self.nodes.append(Node(start))
    self.trail[start] = Node(start)
    visited = defaultdict(lambda: False)
    # visited = [False] * (max(self.graph) + 1)
    queue = []
    count = 0

    queue.append(start)
    visited[start] = True

    while queue:
      node = queue.pop(0)
      self.extendGraph(node)
      # print(self.trail[node].data)
      # if node == self.target:
      #   print("Found it!")
      #   path = []
      #   breadcrumbs = self.trail[i]
      #   while breadcrumbs.last is not None:
      #     path.insert(0, breadcrumbs.data)
      #     breadcrumbs = breadcrumbs.last
      #   print(path)
      #   return path
      count += 1
      print(count, node)
      for i in self.graph[node]:
        
        # print(count, node, i, self.trail[node].data, self.trail[i].last.data)#self.trail[node])
        if i == self.target:
          print("Found it here!")
          path = [i]
          breadcrumbs = self.trail[i]
          while breadcrumbs.last != None:
            path.insert(0, breadcrumbs.last.data)
            breadcrumbs = breadcrumbs.last
            #print(breadcrumbs.data)
            #print(breadcrumbs.last.data)
            #print(breadcrumbs.last.last.data)
            # new_node = breadcrumbs.last
            #if breadcrumbs == breadcrumbs.last:
            #  break
            # print(breadcrumbs.last, breadcrumbs, new_node)
            # path.insert(0, new_node.data)
            # breadcrumbs = new_node
            # print(_, breadcrumbs.last, breadcrumbs, new_node)
            


          #path = [start] + self.trail[node] + [self.target]
          print(path)
          return path
        if visited[i] == False:
          queue.append(i)
          #print(i, visited[i], self.target)
          visited[i] = True
          




def find_path(start: str, finish: str) -> List[str]:
    """Find the shortest path from `start` to `finish`

    Arguments:
      start (str): wikipedia article URL to start from
      finish (str): wikipedia article URL to stop at

    Returns:
      urls (list[str]):
        List of URLs representing the path from `start` to `finish`.
        The first item should be `start`.
        The last item should be `finish`.
        All items of the list should be URLs for wikipedia articles.
        Each article should have a direct link to the next article in the list.
    """
    #path = [start]
    """
    start_html = get_html(start)
    found = False

    articles = find_articles(start_html)
    print(articles)
    if finish in articles:
      path.append(finish)

    while not found:
      for article in articles:
        article_html = get_html(article)
        new_articles = find_articles(article_html)
        if finish in articles:
          found = True

    """
    graph = Graph(finish)
    path = graph.Search(start)
    assert path[0] == start
    assert path[-1] == finish
    return path

# %%
start = "https://en.wikipedia.org/wiki/The_Emoji_Movie"
finish = "https://en.wikipedia.org/wiki/Vietnam_War"

# %%
find_path(start, finish)
# Out:
# 1 https://en.wikipedia.org/wiki/The_Emoji_Movie
# 2 https://en.wikipedia.org/wiki/Entertainment_Weekly
# 3 https://en.wikipedia.org/wiki/Dakota_Johnson
# 4 https://en.wikipedia.org/wiki/Candy_Crush_Saga
# 5 https://en.wikipedia.org/wiki/Marlon_Wayans
# 6 https://en.wikipedia.org/wiki/Jeremy_Burge
# 7 https://en.wikipedia.org/wiki/Cloudy_with_a_Chance_of_Meatballs_(film)
# 8 https://en.wikipedia.org/wiki/Peach_emoji
# 9 https://en.wikipedia.org/wiki/Fandango_Media
# 10 https://en.wikipedia.org/wiki/Brad_Pitt
# 11 https://en.wikipedia.org/wiki/4K_Ultra_HD_Blu-ray
# 12 https://en.wikipedia.org/wiki/Katie_Holmes
# 13 https://en.wikipedia.org/wiki/Ricky_Blitt
# 14 https://en.wikipedia.org/wiki/Bewitched_(2005_film)
# 15 https://en.wikipedia.org/wiki/Warner_Bros._Pictures
# 16 https://en.wikipedia.org/wiki/LeBron_James
# 17 https://en.wikipedia.org/wiki/Leonard_Part_6
# 18 https://en.wikipedia.org/wiki/Cartoon_Brew
# 19 https://en.wikipedia.org/wiki/Eddie_Murphy
# ...

# %%
# %load_ext line_profiler

# %%
import requests
from collections import defaultdict
import concurrent.futures

CONNECTIONS = 100
TIMEOUT = 5

S = requests.Session()
headers = {
    "User-Agent": "august.femtehjell@gmail.com Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"
}



def API_articles(name):
    URL = "https://en.wikipedia.org/w/api.php"
    articles = set()
    PARAMS = {
        "action": "query",
        "format": "json",
        "titles": name,
        "prop": "links",
        "pllimit": "max"
        }
    R = S.get(url=URL, params=PARAMS, headers=headers)
    DATA = R.json()

    PAGES = DATA["query"]["pages"]

    for k, v in PAGES.items():
        if "links" in v:
          for l in v["links"]:
              articles.add(l["title"])
    return articles

class Node:
  def __init__(self, data):
    self.data = data
    self.last = None

class Graph:

  def __init__(self, target):
    self.graph = defaultdict(list)
    self.trail = {}
    self.target = target

  def extendGraph(self, name):
    articles = API_articles(name)
    for article in articles:
      if article != name:
        self.addEdge(name, article)

  def addEdge(self, u, v):
    self.graph[u].append(v)
    
    if not v in self.trail:
      node = Node(v)
      self.trail[v] = node
      node.last = self.trail[u]

  def Search(self, start):
    self.trail[start] = Node(start)
    visited = defaultdict(lambda: False)
    queue = []
    count = 0

    queue.append(start)
    visited[start] = True

    while queue:
      node = queue.pop(0)
      self.extendGraph(node)
      count += 1
      print(count, node)
      for i in self.graph[node]:
        if i == self.target:
          print("Found it here!")
          path = [i]
          breadcrumbs = self.trail[i]
          while breadcrumbs.last != None:
            path.insert(0, breadcrumbs.last.data)
            breadcrumbs = breadcrumbs.last
            
          print(path)
          return path
        if visited[i] == False:
          queue.append(i)
          visited[i] = True
          
def find_path(start, finish):
  graph = Graph(finish)
  path = graph.Search(start)
  assert path[0] == start
  assert path[-1] == finish
  return path

# %%
start = "Python (programming language)"
finish = "Peace"

# %%
# %lprun -f API_articles -f Graph.extendGraph -f Graph.addEdge -f Graph.Search find_path(start, finish)
# Out:
# UsageError: Line magic function `%lprun` not found.

# %%
# %timeit API_articles("RKWard")
# Out:
# 145 ms ± 1.51 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
